# %%
from google.colab import drive
drive.mount('/content/drive')
print("Drive mounted")
# Out:
# Mounted at /content/drive
# Drive mounted

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dynamic pricing /Product Data.csv')
print("File loaded")
# Out:
# File loaded

# %%
df.head()
# Out:
#    Product_ID  Category   Brand  Season Product_Name  Original_Price  \
# 0           1  Skincare  BrandA  Summer    Sunscreen           70.39
# 1           2  Skincare  BrandB   Rainy    Eye Cream           55.35
# 2           3  Skincare  BrandA  Spring    Face Mist           26.16
# 3           4  Bodycare  BrandD  Winter   Shower Gel           99.34
# 4           5  Skincare  BrandA  Winter  Peeling Gel           60.33
#
#    Competitor_Price  Seasonality_Factor  Markdown_1  Markdown_2  ...  \
# 0             70.98                1.71        0.31        0.49  ...
# 1             56.58                0.85        0.39        0.21  ...
# 2             28.54                1.03        0.17        0.43  ...
# 3             98.57                1.91        0.20        0.21  ...
# 4             61.05                1.65        0.14        0.20  ...
#
#    Historical_Sales  Sales_After_M1  Sales_After_M2  Sales_After_M3  \
# 0               344             404             540             650
# 1                98             107             116             118
# 2                72              72              87              84
# 3               243             281             316             361
# 4               251             289             325             402
#
#    Sales_After_M4  Stock_Level  Promotion_Type  Customer Ratings Return Rate  \
# 0             979          183        In-Store               4.9        1.97
# 1             143          142          Online               4.0        2.57
# 2              84          112    Social Media               2.3        4.64
# 3             539           57        In-Store               4.9        1.42
# 4             534          125        In-Store               4.6        1.36
#
#    Optimal Discount
# 0              0.36
# 1              0.29
# 2              0.33
# 3              0.25
# 4              0.23
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#        Product_ID  Category   Brand  Season    Product_Name  Original_Price  \
# 43745       39541  Skincare  BrandF  Summer      Face Toner           51.71
# 43746       18153  Skincare  BrandA  Spring  Hydrating Mask           25.62
# 43747       14665  Bodycare  BrandA   Rainy       Body Balm           49.31
# 43748        7290  Bodycare  BrandB  Spring     Body Powder            5.79
# 43749       27552    Makeup  BrandB  Spring        Lipstick           39.26
#
#        Competitor_Price  Seasonality_Factor  Markdown_1  Markdown_2  ...  \
# 43745             54.51                1.58        0.22        0.33  ...
# 43746             26.40                1.17        0.21        0.40  ...
# 43747             49.58                1.09        0.13        0.34  ...
# 43748              4.85                0.87        0.10        0.24  ...
# 43749             40.65                1.54        0.16        0.22  ...
#
#        Historical_Sales  Sales_After_M1  Sales_After_M2  Sales_After_M3  \
# 43745                79              91             117             142
# 43746               140             141             132             139
# 43747               126             144             178             202
# 43748                94              94             103             100
# 43749               117             129             159             181
#
#        Sales_After_M4  Stock_Level  Promotion_Type  Customer Ratings  \
# 43745             208          130        In-Store               4.7
# 43746             152          158    Social Media               4.4
# 43747             249          180          Online               4.7
# 43748             108           97    Social Media               4.4
# 43749             274           87        In-Store               4.9
#
#       Return Rate  Optimal Discount
# 43745        1.69              0.30
# 43746        2.34              0.32
# 43747        1.52              0.26
# 43748        3.16              0.25
# 43749        1.67              0.28
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (43750, 22)

# %%
df.describe()
# Out:
#          Product_ID  Original_Price  Competitor_Price  Seasonality_Factor  \
# count  43750.000000    43750.000000      43750.000000        43750.000000
# mean   21705.645051       52.659917         53.648610            1.328372
# std    12526.600860       27.515733         27.542159            0.466122
# min        1.000000        5.000000          4.100000            0.500000
# 25%    10863.250000       28.820000         29.800000            0.900000
# 50%    21705.500000       52.840000         53.835000            1.500000
# 75%    32550.750000       76.630000         77.597500            1.750000
# max    43400.000000      100.000000        102.960000            2.000000
#
#          Markdown_1    Markdown_2    Markdown_3    Markdown_4  \
# count  43750.000000  43750.000000  43750.000000  43750.000000
# mean       0.250620      0.350107      0.199834      0.400097
# std        0.086428      0.086604      0.057907      0.057977
# min        0.100000      0.200000      0.100000      0.300000
# 25%        0.180000      0.280000      0.150000      0.350000
# 50%        0.250000      0.350000      0.200000      0.400000
# 75%        0.330000      0.430000      0.250000      0.450000
# max        0.400000      0.500000      0.300000      0.500000
#
#        Historical_Sales  Sales_After_M1  Sales_After_M2  Sales_After_M3  \
# count      43750.000000    43750.000000    43750.000000    43750.000000
# mean         171.893554      201.142171      250.353897      286.513623
# std           88.500750      111.765796      152.876420      184.139572
# min           26.000000       26.000000       25.000000       26.000000
# 25%          101.000000      113.000000      128.000000      137.000000
# 50%          154.000000      175.000000      210.000000      236.000000
# 75%          233.000000      276.000000      357.000000      415.000000
# max          416.000000      579.000000      844.000000     1114.000000
#
#        Sales_After_M4   Stock_Level  Customer Ratings   Return Rate  \
# count    43750.000000  43750.000000      43750.000000  43750.000000
# mean       370.565303    124.854469          4.290862      2.203713
# std        258.253190     43.211560          0.810869      1.258030
# min         25.000000     50.000000          2.000000      1.000000
# 25%        152.000000     88.000000          4.000000      1.360000
# 50%        299.000000    124.000000          4.600000      1.720000
# 75%        555.000000    162.000000          4.800000      2.600000
# max       1535.000000    200.000000          5.000000      6.000000
#
#        Optimal Discount
# count      43750.000000
# mean           0.300373
# std            0.036854
# min            0.180000
# 25%            0.280000
# 50%            0.300000
# 75%            0.320000
# max            0.420000

# %%
df.isnull().sum()
# Out:
# Product_ID            0
# Category              0
# Brand                 0
# Season                0
# Product_Name          0
# Original_Price        0
# Competitor_Price      0
# Seasonality_Factor    0
# Markdown_1            0
# Markdown_2            0
# Markdown_3            0
# Markdown_4            0
# Historical_Sales      0
# Sales_After_M1        0
# Sales_After_M2        0
# Sales_After_M3        0
# Sales_After_M4        0
# Stock_Level           0
# Promotion_Type        0
# Customer Ratings      0
# Return Rate           0
# Optimal Discount      0
# dtype: int64

# %%
print("Duplicates before:", df.duplicated().sum())
# Out:
# Duplicates before: 350

# %%
df = df.drop_duplicates()

# %%
print("Duplicates after:", df.duplicated().sum())
print("New shape:", df.shape)
# Out:
# Duplicates after: 0
# New shape: (43400, 22)

# %%
df.columns
# Out:
# Index(['Product_ID', 'Category', 'Brand', 'Season', 'Product_Name',
#        'Original_Price', 'Competitor_Price', 'Seasonality_Factor',
#        'Markdown_1', 'Markdown_2', 'Markdown_3', 'Markdown_4',
#        'Historical_Sales', 'Sales_After_M1', 'Sales_After_M2',
#        'Sales_After_M3', 'Sales_After_M4', 'Stock_Level', 'Promotion_Type',
#        'Customer Ratings', 'Return Rate', 'Optimal Discount'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Product_ID              int64
# Category               object
# Brand                  object
# Season                 object
# Product_Name           object
# Original_Price        float64
# Competitor_Price      float64
# Seasonality_Factor    float64
# Markdown_1            float64
# Markdown_2            float64
# Markdown_3            float64
# Markdown_4            float64
# Historical_Sales        int64
# Sales_After_M1          int64
# Sales_After_M2          int64
# Sales_After_M3          int64
# Sales_After_M4          int64
# Stock_Level             int64
# Promotion_Type         object
# Customer Ratings      float64
# Return Rate           float64
# Optimal Discount      float64
# dtype: object

# %%
numeric_cols = ['Original_Price','Competitor_Price','Historical_Sales','Sales_After_M1','Sales_After_M2',
                'Sales_After_M3','Sales_After_M4','Stock_Level','Customer Ratings','Return Rate','Optimal Discount']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in numeric_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
for col in numeric_cols:
    lower = df[col].quantile(0.01)
    upper = df[col].quantile(0.99)
    df[col] = df[col].clip(lower, upper)
# Out:
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)
# /tmp/ipython-input-3648009258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower, upper)

# %%
for col in numeric_cols:
    print(f"{col} min: {df[col].min()}, max: {df[col].max()}")
# Out:
# Original_Price min: 5.85, max: 99.02
# Competitor_Price min: 6.66, max: 100.16
# Historical_Sales min: 37, max: 382
# Sales_After_M1 min: 39, max: 477
# Sales_After_M2 min: 42, max: 638
# Sales_After_M3 min: 43, max: 755
# Sales_After_M4 min: 46, max: 1031
# Stock_Level min: 52, max: 198
# Customer Ratings min: 2.1, max: 5.0
# Return Rate min: 1.01, max: 5.84
# Optimal Discount min: 0.22, max: 0.38

# %%
assert (df['Historical_Sales'] >= 0).all()
assert (df[['Sales_After_M1','Sales_After_M2','Sales_After_M3','Sales_After_M4']] >= 0).all().all()
assert (df['Original_Price'] > 0).all()
assert (df['Competitor_Price'] > 0).all()
assert (df['Return Rate'].between(0,100)).all()
assert (df['Customer Ratings'].between(0,5)).all()
assert (df['Optimal Discount'].between(0,100)).all()

# %%
df['Total_Sales_After'] = df[['Sales_After_M1','Sales_After_M2','Sales_After_M3','Sales_After_M4']].sum(axis=1)
df['Avg_Markdown'] = df[['Markdown_1','Markdown_2','Markdown_3','Markdown_4']].mean(axis=1)
# Out:
# /tmp/ipython-input-2022224994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Sales_After'] = df[['Sales_After_M1','Sales_After_M2','Sales_After_M3','Sales_After_M4']].sum(axis=1)
# /tmp/ipython-input-2022224994.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Avg_Markdown'] = df[['Markdown_1','Markdown_2','Markdown_3','Markdown_4']].mean(axis=1)

# %%
df.to_csv('Cleaned_ProductData.csv', index=False)
